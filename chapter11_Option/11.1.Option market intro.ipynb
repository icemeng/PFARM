# %%
##########################################################################
# Created on Sat Nov 13 00:43:45 2021                                    #
# Python for Financial Analysis and Risk Management                      #
# @author: Meng Lipeng (FRM, CFA)                                        #
##########################################################################

# %% [markdown]
# # 11.1.2.Stock option

# %%
import pandas as pd
import matplotlib.pyplot as plt

option_300ETF=pd.read_excel('300ETF Call 3500 daily.xlsx',engine='openpyxl',sheet_name="Sheet1",header=0,index_col=0)

option_300ETF.plot(figsize=(13,6),title='300 ETF Call 3500 daily',grid=True,fontsize=13)
plt.ylabel('Price',fontsize=11)
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# # 11.1.3.Stock Index option

# %%
option_HS300=pd.read_excel('HS300 Put 4000 daily.xlsx',engine='openpyxl',sheet_name="Sheet1",header=0,index_col=0)

option_HS300.plot(figsize=(13,6),title='HS300 Put 4000 daily',grid=True,fontsize=13)
plt.ylabel('Price',fontsize=11)
# Out:
# Text(0, 0.5, 'Price')
