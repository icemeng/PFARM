# %%
##########################################################################
# Created on Sat Otc 31 14:36:45 2021                                    #
# Python for Financial Analysis and Risk Management                      #
# @author: Meng Lipeng (FRM, CFA)                                        #
##########################################################################

# %% [markdown]
# # 6.1.2.Interest rate of financial institutions

# %%
import pandas as pd
import matplotlib.pyplot as plt

LPR=pd.read_excel('Loan Prime Rate(LPR).xlsx',engine='openpyxl',sheet_name="Sheet1",header=0,index_col=0)
LPR.plot(figsize=(9,6),grid=True,fontsize=13)
plt.ylabel('IR',fontsize=13)
# Out:
# Text(0, 0.5, 'IR')

# %% [markdown]
# # 6.1.3.Financial market interest rate

# %%
IBL=pd.read_excel('Interbank Lending Rate(2019-2020).xlsx',engine='openpyxl',sheet_name="Sheet1",header=0,index_col=0)
IBL.plot(figsize=(9,6),grid=True,fontsize=13)
plt.ylabel('IR',fontsize=13)
# Out:
# Text(0, 0.5, 'IR')

# %%
FR=pd.read_excel('Fixing Repo Rate(2019-2020).xlsx',engine='openpyxl',sheet_name="Sheet1",header=0,index_col=0)
FR.plot(figsize=(9,6),grid=True,fontsize=13)
plt.ylabel('IR',fontsize=13)
# Out:
# Text(0, 0.5, 'IR')

# %%
Shibor=pd.read_excel('Shibor(2019-2020).xlsx',engine='openpyxl',sheet_name="Sheet1",header=0,index_col=0)
Shibor.plot(figsize=(9,6),grid=True,fontsize=13)
plt.ylabel('IR',fontsize=13)
# Out:
# Text(0, 0.5, 'IR')
