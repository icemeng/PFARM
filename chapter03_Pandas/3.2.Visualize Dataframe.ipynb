# %%
##########################################################################
# Created on Sat Otc 26 23:59:45 2021                                    #
# Python for Financial Analysis and Risk Management                      #
# @author: Meng Lipeng (FRM, CFA)                                        #
##########################################################################

# %% [markdown]
# # 3.2.1.Chinese font

# %%
from pylab import plt
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False
#Can't be visualized correctly because lack of Chinese font in 
#/home/ec2-user/SageMaker/custom-miniconda/miniconda/envs/custom_python/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf

# %% [markdown]
# # 3.2.2.Dataframe visualization

# %%
import pandas as pd
SH_Index=pd.read_excel('SHIndex_2020.xlsx',engine='openpyxl',sheet_name="Sheet1",header=0,index_col=0)

# %%
SH_Index.plot(kind='line',subplots=True,sharex=True,sharey=True,layout=(2,2),figsize=(11,9),title=u'SHIndex daily of 2020',grid=True,fontsize=13)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff29815e2e8>,
# ...
#       dtype=object)

# %%
import matplotlib    
print(matplotlib.matplotlib_fname())
# Out:
# /home/ec2-user/SageMaker/custom-miniconda/miniconda/envs/custom_python/lib/python3.6/site-packages/matplotlib/mpl-data/matplotlibrc
